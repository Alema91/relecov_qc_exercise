# %%
import seaborn as sns
import pandas as pd

sheet1, sheet2 = None, None
with pd.ExcelFile(
    "/home/erika.kvalem/Documents/Relecov/relecov_qc_exercise/files/QC_final.xlsx"
) as reader:
    df = pd.read_excel(reader, sheet_name="resultados")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                400 non-null    object
#  1   Sample ID                         400 non-null    object
#  2   Protocolo diagnostico SARS-CoV-2  390 non-null    object
#  3   var_protocolo_diagnostico         390 non-null    object
#  4   Variante                          355 non-null    object
#  5   Asignacion de Linaje              384 non-null    object
#  6   Version Pango                     394 non-null    object
#  7   Valor Ct PCR                      280 non-null    float64
#  8   Valor Ct N                        60 non-null     float64
#  9   Valor Ct ORF                      30 non-null     float64
#  10  Valor Ct S                        35 non-null     float64
#  11  var_readcount                     389 non-null    float64
#  12  var_qcfiltered                    253 non-null    float64
#  13  var_readhost                      228 non-null    float64
#  14  var_readsvirus                    352 non-null    float64
#  15  var_unmapped                      310 non-null    float64
#  16  var_QC>10x                        317 non-null    float64
#  17  var_mean_depth_coverage           378 non-null    float64
#  18  var_n_Ns                          337 non-null    float64
#  19  var_number_variants_75            252 non-null    float64
#  20  var_variantseffect                279 non-null    float64
#  21  var_referencegenomeaccession      389 non-null    object
# dtypes: float64(14), object(8)
# memory usage: 68.9+ KB

# %% [markdown]
# # 1 gráfica

# %%
df
# Out:
#            ID Sample ID                   Protocolo diagnostico SARS-CoV-2  \
# 0    COD_2102        #1  PCR TaqMan ™ 2019-nCoV Assay Kit v1 (referenci...
# 1    COD_2102        #2  PCR TaqMan ™ 2019-nCoV Assay Kit v1 (referenci...
# 2    COD_2102        #3  PCR TaqMan ™ 2019-nCoV Assay Kit v1 (referenci...
# 3    COD_2102        #4  PCR TaqMan ™ 2019-nCoV Assay Kit v1 (referenci...
# 4    COD_2102        #5  PCR TaqMan ™ 2019-nCoV Assay Kit v1 (referenci...
# ..        ...       ...                                                ...
# 395  COD_2143        #6                                   in house RT-qPCR
# 396  COD_2143        #7                                   in house RT-qPCR
# 397  COD_2143        #8                                   in house RT-qPCR
# 398  COD_2143        #9                                   in house RT-qPCR
# 399  COD_2143       #10                                   in house RT-qPCR
#
#       var_protocolo_diagnostico                Variante Asignacion de Linaje  \
# 0    RT-PCR 2019-nCoV Assay kit                 B.1.1.7      20I (Alpha, V1)
# 1    RT-PCR 2019-nCoV Assay kit                 B.1.351       20H (Beta, V2)
# 2    RT-PCR 2019-nCoV Assay kit                    A.28                  19B
# 3    RT-PCR 2019-nCoV Assay kit                 B.1.621             21H (Mu)
# 4    RT-PCR 2019-nCoV Assay kit                     P.1      20J (Gamma, V3)
# ..                          ...                     ...                  ...
# 395            in house RT-qPCR  Delta (B.1.617.2-like)               AY.9.2
# 396            in house RT-qPCR  Delta (B.1.617.2-like)                AY.43
# 397            in house RT-qPCR  Delta (B.1.617.2-like)                AY.94
# 398            in house RT-qPCR  Delta (B.1.617.2-like)                AY.94
# 399            in house RT-qPCR  Delta (B.1.617.2-like)                AY.43
#
#            Version Pango  Valor Ct PCR  Valor Ct N  Valor Ct ORF  ...  \
# 0    2017-01-03 00:00:00           NaN        16.0          19.0  ...
# 1    2017-01-03 00:00:00           NaN        15.0          18.0  ...
# 2    2017-01-03 00:00:00           NaN        18.0          20.0  ...
# 3    2017-01-03 00:00:00           NaN        18.0          20.0  ...
# 4    2017-01-03 00:00:00           NaN        18.0          21.0  ...
# ..                   ...           ...         ...           ...  ...
# 395               3.1.17          25.2         NaN           NaN  ...
# 396               3.1.17          26.3         NaN           NaN  ...
# 397               3.1.17          21.1         NaN           NaN  ...
# 398               3.1.17          20.3         NaN           NaN  ...
# 399               3.1.17          21.3         NaN           NaN  ...
#
#      var_qcfiltered  var_readhost  var_readsvirus  var_unmapped  var_QC>10x  \
# 0             99.90           0.1           99.90        1.0000       99.00
# 1             99.90           0.1           99.90        1.0000       99.00
# 2             99.90           0.1           99.90        1.0000       99.00
# 3             99.90           0.1           99.90        1.0000       99.00
# 4             99.90           0.1           99.90        1.0000       99.00
# ..              ...           ...             ...           ...         ...
# 395           89.55           NaN           99.94        0.0006       95.55
# 396           89.96           NaN           99.97        0.0003       95.95
# 397           89.71           NaN           99.96        0.0004       95.95
# 398           88.29           NaN           99.93        0.0007       95.95
# 399           88.69           NaN           99.95        0.0005       95.95
#
#      var_mean_depth_coverage  var_n_Ns  var_number_variants_75  \
# 0                   2877.000       NaN                    36.0
# 1                   2800.000       NaN                    28.0
# 2                   2494.000       NaN                    25.0
# 3                   2217.000       NaN                    37.0
# 4                   1041.000       NaN                    37.0
# ..                       ...       ...                     ...
# 395                    3.923       0.0                    37.0
# 396                    3.934       0.0                    41.0
# 397                    2.745       0.0                    42.0
# 398                    3.824       0.0                    42.0
# 399                    5.175       0.0                    41.0
#
#      var_variantseffect  var_referencegenomeaccession
# 0                  28.0                      MN908947
# 1                  26.0                      MN908947
# 2                  17.0                      MN908947
# 3                  28.0                      MN908947
# 4                  30.0                      MN908947
# ..                  ...                           ...
# 395                25.0                   NC_045512.2
# 396                30.0                   NC_045512.2
# 397                30.0                   NC_045512.2
# 398                30.0                   NC_045512.2
# 399                30.0                   NC_045512.2
#
# [400 rows x 22 columns]

# %%
data = [df["ID"],df["Sample ID"], df["var_readcount"],df["var_qcfiltered"]]

headers = ["ID","sample_id","var_readcount","var_qcfiltered"]

df2 = pd.concat(data, axis=1, keys=headers)

# %%
df2['reads_post_trimming'] = df2['var_readcount']*df2['var_qcfiltered'] /100

# %%
df2.isnull().sum()
# Out:
# ID                       0
# sample_id                0
# var_readcount           11
# var_qcfiltered         147
# reads_post_trimming    147
# dtype: int64

# %%
df2
# Out:
#            ID sample_id  var_readcount  var_qcfiltered  reads_post_trimming
# 0    COD_2102        #1       682115.0           99.90          681432.8850
# 1    COD_2102        #2       680035.0           99.90          679354.9650
# 2    COD_2102        #3       591253.0           99.90          590661.7470
# 3    COD_2102        #4       525910.0           99.90          525384.0900
# 4    COD_2102        #5       247292.0           99.90          247044.7080
# ..        ...       ...            ...             ...                  ...
# 395  COD_2143        #6       621207.0           89.55          556290.8685
# 396  COD_2143        #7       606958.0           89.96          546019.4168
# 397  COD_2143        #8       460721.0           89.71          413312.8091
# 398  COD_2143        #9       607880.0           88.29          536697.2520
# 399  COD_2143       #10       809170.0           88.69          717652.8730
#
# [400 rows x 5 columns]

# %% [markdown]
# # Valores nulos

# %%
df2.isna().sum()
# Out:
# ID                       0
# sample_id                0
# var_readcount           11
# var_qcfiltered         147
# reads_post_trimming    147
# dtype: int64

# %%
df2.dropna( subset = ['var_qcfiltered'], inplace = True )

df2= df2.astype({'var_qcfiltered': int})

# %%
data = [df2["ID"],df2["sample_id"],df2["var_unmapped"]]

headers = ["ID","sample_id","var_unmapped"]

sub_dataf = pd.concat(data, axis=1, keys=headers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var_unmapped'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 data = [df2["ID"],df2["sample_id"],df2["var_unmapped"]]
#       3 headers = ["ID","sample_id","var_unmapped"]
#       5 sub_dataf = pd.concat(data, axis=1, keys=headers)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'var_unmapped'

# %%
nan_df = sub_dataf[sub_dataf['var_unmapped'].isna()]

# %%
nan_df
# Out:
#              ID sample_id  var_unmapped
# 16     COD_2103        #7           NaN
# 20     COD_2104        #1           NaN
# 21     COD_2104        #2           NaN
# 22     COD_2104        #3           NaN
# 23     COD_2104        #4           NaN
# 24     COD_2104        #5           NaN
# 25     COD_2104        #6           NaN
# 26     COD_2104        #7           NaN
# 27     COD_2104        #8           NaN
# 28     COD_2104        #9           NaN
# 29     COD_2104       #10           NaN
# 46     COD_2106        #7           NaN
# 70   COD_2107_2        #1           NaN
# 71   COD_2107_2        #2           NaN
# 72   COD_2107_2        #3           NaN
# 73   COD_2107_2        #4           NaN
# 74   COD_2107_2        #5           NaN
# 75   COD_2107_2        #6           NaN
# 76   COD_2107_2        #7           NaN
# 77   COD_2107_2        #8           NaN
# 78   COD_2107_2        #9           NaN
# 79   COD_2107_2       #10           NaN
# 86     COD_2108        #7           NaN
# 100    COD_2110        #1           NaN
# 101    COD_2110        #2           NaN
# 102    COD_2110        #3           NaN
# 103    COD_2110        #4           NaN
# 104    COD_2110        #5           NaN
# 105    COD_2110        #6           NaN
# 106    COD_2110        #7           NaN
# 107    COD_2110        #8           NaN
# 108    COD_2110        #9           NaN
# 109    COD_2110       #10           NaN
# 116    COD_2111        #7           NaN
# 166    COD_2116        #7           NaN
# 176    COD_2117        #7           NaN
# 180  COD_2117_2        #1           NaN
# 181  COD_2117_2        #2           NaN
# 182  COD_2117_2        #3           NaN
# 183  COD_2117_2        #4           NaN
# 184  COD_2117_2        #5           NaN
# 185  COD_2117_2        #6           NaN
# 186  COD_2117_2        #7           NaN
# 187  COD_2117_2        #8           NaN
# 188  COD_2117_2        #9           NaN
# 189  COD_2117_2       #10           NaN
# 200    COD_2120        #1           NaN
# 201    COD_2120        #2           NaN
# 202    COD_2120        #3           NaN
# 203    COD_2120        #4           NaN
# 204    COD_2120        #5           NaN
# 205    COD_2120        #6           NaN
# 206    COD_2120        #7           NaN
# 207    COD_2120        #8           NaN
# 208    COD_2120        #9           NaN
# 209    COD_2120       #10           NaN
# 216    COD_2121        #7           NaN
# 220    COD_2122        #1           NaN
# 221    COD_2122        #2           NaN
# 222    COD_2122        #3           NaN
# 223    COD_2122        #4           NaN
# 224    COD_2122        #5           NaN
# 225    COD_2122        #6           NaN
# 226    COD_2122        #7           NaN
# 227    COD_2122        #8           NaN
# 228    COD_2122        #9           NaN
# 229    COD_2122       #10           NaN
# 245    COD_2124        #6           NaN
# 256  COD_2124_2        #7           NaN
# 286    COD_2127        #7           NaN
# 300    COD_2131        #1           NaN
# 301    COD_2131        #2           NaN
# 302    COD_2131        #3           NaN
# 303    COD_2131        #4           NaN
# 304    COD_2131        #5           NaN
# 305    COD_2131        #6           NaN
# 306    COD_2131        #7           NaN
# 307    COD_2131        #8           NaN
# 308    COD_2131        #9           NaN
# 309    COD_2131       #10           NaN
# 310    COD_2132        #1           NaN
# 311    COD_2132        #2           NaN
# 312    COD_2132        #3           NaN
# 313    COD_2132        #4           NaN
# 314    COD_2132        #5           NaN
# 315    COD_2132        #6           NaN
# 316    COD_2132        #7           NaN
# 317    COD_2132        #8           NaN
# 318    COD_2132        #9           NaN
# 319    COD_2132       #10           NaN

# %%
nan_df.drop(columns=['var_unmapped'], inplace = True)
# Out:
# /home/erika.kvalem/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
nan_df.groupby(['ID']).count()
# Out:
#             sample_id
# ID
# COD_2103            1
# COD_2104           10
# COD_2106            1
# COD_2107_2         10
# COD_2108            1
# COD_2110           10
# COD_2111            1
# COD_2116            1
# COD_2117            1
# COD_2117_2         10
# COD_2120           10
# COD_2121            1
# COD_2122           10
# COD_2124            1
# COD_2124_2          1
# COD_2127            1
# COD_2131           10
# COD_2132           10

# %%
import matplotlib
sns.set(rc={'figure.figsize':(13.7,9.27)})
ax = sns.boxplot(x="ID", y="reads_post_trimming", data=df2)
ax.tick_params(axis='x', rotation=90)
ax.set(xlabel='Laboratories', ylabel='Count Reads POST trimming * 10⁶')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 5>()
#       3 ax.tick_params(axis='x', rotation=90)
#       4 ax.set(xlabel='Laboratories', ylabel='Count Reads POST trimming * 10⁶')
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Segunda grafica

# %%
del df2

# %%
data = [df["ID"],df["Sample ID"], df["var_readhost"],df["var_readsvirus"],df["var_unmapped"]]

headers = ["ID","sample_id","var_readhost","var_readvirus","var_unmapped"]

df2 = pd.concat(data, axis=1, keys=headers)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             400 non-null    object
#  1   sample_id      400 non-null    object
#  2   var_readhost   228 non-null    float64
#  3   var_readvirus  352 non-null    float64
#  4   var_unmapped   310 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 15.8+ KB

# %%
df2['var_readhost'].max()
# Out:
# 27.9

# %%
pd.set_option('display.max_rows', None)

# %%
select_color = df2.loc[df2['var_readhost'] == 27.9]

# %%
select_color
# Out:
#            ID sample_id  var_readhost  var_readvirus  var_unmapped
# 226  COD_2122        #7          27.9           72.1           NaN

# %%
df2.drop(index=226, inplace = True)

# %%
df2['var_readhost'].max()
# Out:
# 4.8

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
#sns.set(rc={'figure.figsize':(13.7,9.27)})
ax = sns.boxplot(x="sample_id", y="var_unmapped", data=df2)
ax.tick_params(axis='x', rotation=90)
ax.set(xlabel='Samples', ylabel='% Unmapped')
plt.show()

# %%
The best way is to interact with the axes object directly

import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 10, 0.1)
y1 = 0.05 * x**2
y2 = -1 *y1

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
ax2.set_ylabel('Y2 data', color='b')

plt.show()
